# %%
import bs4
from bs4 import BeautifulSoup
import requests as rq

calink='https://www.aninews.in/topic/coronavirus/'
ca=rq.get(calink)
casoap=bs4.BeautifulSoup(ca.content,'html.parser')
cadiv=casoap.find_all('div',class_='c-posts c-posts--mini c-posts--column  c-posts--loadMore')
print(casoap)
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]>      <html class="no-js lt-ie9 lt-ie8 lt-ie7" lang=""> <![endif]-->
# <!--[if IE 7]>         <html class="no-js lt-ie9 lt-ie8" lang=""> <![endif]-->
# <!--[if IE 8]>         <html class="no-js lt-ie9" lang=""> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="no-js" itemscope="" lang="en" xmlns:og="http://opengraphprotocol.org/schema/">
# <!--<![endif]-->
# <head>
# <meta charset="utf-8"/>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title>Latest News on coronavirus - ANI News - Asia’s Premier News Agency</title>
# <meta content="index, follow" name="robots">
# <!-- google site verification  -->
# <meta content="nl-RnVdNaFwFB5q0TRy6Yoh1eRvbcouKZFM7dQlc4Zo" name="google-site-verification">
# <!-- facebook instant article  -->
# <meta content="140763992703039" property="fb:pages">
# <meta content="“en”" http-equiv="“content-language”"/>
# ...
